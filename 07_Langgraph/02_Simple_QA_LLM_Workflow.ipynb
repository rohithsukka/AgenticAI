# %% [markdown]
# # Imports

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %% [markdown]
# # Loading env variables

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Define LLM

# %%
llm = ChatGroq(
    model="qwen/qwen3-32b"    # other params...
)

# %% [markdown]
# # Define State

# %%
# create a state
class LLMState(TypedDict):

    question: str
    answer: str

# %% [markdown]
# # Creating Node

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following questions {question}'

    # ask that question to the llm
    answer = llm.invoke(prompt).content

    #update the answer in the state
    state['answer'] = answer

    return state

# %%
# creae our graph

graph = StateGraph(LLMState)

#add nodes 
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

#compile
workflow = graph.compile()

# %% [markdown]
# # Execute the Graph

# %%
# execute

initial_state = {'question' : 'who is the creator of python?'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# <think>
# Okay, so I need to figure out who the creator of Python is. Let me start by recalling what I know. I remember that Python is a programming language, and it's pretty popular for things like web development, data science, and automation. But who created it?
#
# Hmm, I think the creator's name might be Guido van something. Maybe Guido van Rossum? I've heard that name before in the context of Python. Let me try to remember if there's any other info. I think he worked in the Netherlands. Was he at a university or a company? Maybe he was a researcher or a software developer.
#
# I should also consider if there are other possible names. Sometimes there's a common misconception about who created certain technologies. For example, someone might confuse him with someone else. But I'm pretty sure it's Guido van Rossum. Let me think about the timeline. Python was first released in the late 80s or early 90s? I think the first version was in 1991. So Guido developed it around that time.
#
# Wait, was Python developed at a company like Google or Microsoft? Or was it an independent project? I believe Guido started it as a hobby project. He was working at Centrum Wiskunde & Informatica (CWI) in the Netherlands. So, he created Python in the late 1980s as a successor to the ABC programming language. ABC was another language he worked on, and Python was meant to be an improvement.
#
# Also, Guido van Rossum has been known as the "Benevolent Dictator For Life" (BDFL) of the Python community for a long time, which is a title given to him for his role in guiding the development of Python. But I think he stepped down from that role in 2018 or 2019. That might be a key point to mention if the question is about his current status, but the question specifically asks for the creator, so the answer is him regardless.
#
# I should also verify if there's any other person who has been credited. Sometimes open-source projects have multiple contributors, but the original creator is usually the one who initiated it. In Python's case, it's definitely Guido van Rossum. I don't think there's another person who is considered the main creator. There might be other contributors over the years, but he's the one who created the language.
#
# Another thing to check: sometimes there's confusion with other languages. For example, the creator of Java is James Gosling, Python is different. So no confusion there. Guido van Rossum is the correct answer here.
# </think>
#
# The creator of Python is **Guido van Rossum**, a Dutch programmer. He began developing Python in the late 1980s while working at the Centrum Wiskunde & Informatica (CWI) in the Netherlands. Python was officially released in 1991 as a successor to the ABC programming language, with the goal of creating a more readable and user-friendly language.
#
# Van Rossum played a central role in Python's development for decades, earning the informal title of "Benevolent Dictator For Life" (BDFL) for his leadership in guiding the language's evolution. He stepped down from this role in 2018, marking a transition in Python's governance to the Python Software Foundation.
#
# Today, Guido van Rossum is widely recognized as the visionary behind Python, which has become one of the most popular programming languages globally.

# %% [markdown]
# # Visualize Graph (optional)

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())
